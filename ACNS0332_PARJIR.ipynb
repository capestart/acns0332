# %%
import process_annotations

# %%
patient_id = 'PARJIR'
patient_age = '010Y'
patient_sex = 'M'

base_path = patient_id + '/'
patient_name = 'ACNS0332_' + patient_id

# %%
process_annotations.prepare_annotations(base_path)

# %%
process_annotations.process_timepoint(base_path, 1, patient_name, patient_age, patient_sex)
process_annotations.process_timepoint(base_path, 2, patient_name, patient_age, patient_sex)
process_annotations.process_timepoint(base_path, 3, patient_name, patient_age, patient_sex)
process_annotations.process_timepoint(base_path, 4, patient_name, patient_age, patient_sex)
process_annotations.process_timepoint(base_path, 5, patient_name, patient_age, patient_sex)
# Out:
# Pre-operative FOUND
# Processing SEG file:  PARJIR//Annotations/1-Pre-Operative/SEG_20211223_002454_076_S6.dcm
# Processing RTSS file:  PARJIR//Annotations/1-Pre-Operative/AIM_20211223_002510_393_S6.dcm
# DETECTED ROI NAME:  Edema
# Input SeriesDescription:  1 - FLAIR - pineal - V1
# PatientName:  ACNS0332_PARJIR
# PatientAge:  010Y
# PatientSex:  M
# SeriesDescription:  Pre-operative, 1 - FLAIR - pineal - V1
# SegmentSequence[0].SegmentLabel:  Edema
# segmentation_code:  (0008, 0100) Code Value                          SH: '79654002'
# (0008, 0102) Coding Scheme Designator            SH: 'SCT'
# (0008, 0104) Code Meaning                        LO: 'Edema'
# roi_name:  Edema
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '262068006'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#    ---------
# Output SeriesDescription:  Pre-operative, 1 - FLAIR - pineal - V1
# (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '45793000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#    ---------
# (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '49755003'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#    ---------
# (0062, 0004) Segment Number                      US: 1
# (0062, 0005) Segment Label                       LO: 'Edema'
# (0062, 0008) Segment Algorithm Type              CS: 'MANUAL'
# (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '79654002'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Edema'
#    ---------
# (0062, 0020) Tracking ID                         UT: 'Edema'
# (0062, 0021) Tracking UID                        UI: 2.25.282254060485931654441677076302135519352
# Saved file  PARJIR//Annotations/1-Pre-Operative/SEG_20211223_002454_076_S6.dcm
# SeriesDescription:  Pre-operative, 1 - FLAIR - pineal - V1
# segmentation_code:  (0008, 0100) Code Value                          SH: '79654002'
# (0008, 0102) Coding Scheme Designator            SH: 'SCT'
# (0008, 0104) Code Meaning                        LO: 'Edema'
# roi_name:  Edema
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '262068006'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#    ---------
# (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
# (3006, 0040)  Contour Sequence  1 item(s) ----
#    (3006, 0016)  Contour Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.157563254097513035055775127869
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'POINT'
#    (3006, 0046) Number of Contour Points            IS: '1'
#    (3006, 0048) Contour Number                      IS: '1'
#    (3006, 0050) Contour Data                        DS: [-0.29316994871942503, 12.7742645918689, 7.345938845506385]
#    ---------
# (3006, 0084) Referenced ROI Number               IS: '1'
# (3006, 0022) ROI Number                          IS: '1'
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
# (3006, 0026) ROI Name                            LO: '1 - FLAIR - pineal - V1 - seed point'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 182
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.534147.638.2321637500.20211122185513764
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.534147.638.2321637500.20211122185513764
# (0008, 0020) Study Date                          DA: '19591207'
# (0008, 0021) Series Date                         DA: '20211222'
# (0008, 0030) Study Time                          TM: '075838.875000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTSTRUCT'
# (0008, 0070) Manufacturer                        LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 0110)  Coding Scheme Identification Sequence  3 item(s) ----
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 010c) Coding Scheme UID                   UI: DICOM Controlled Terminology
#    (0008, 0115) Coding Scheme Name                  ST: 'DICOM Controlled Terminology'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'DICOM'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.6.96
#    (0008, 0115) Coding Scheme Name                  ST: 'SNOMED CT'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'SNOMED International'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.3.26.1.1
#    (0008, 0115) Coding Scheme Name                  ST: 'NCI Thesaurus'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'NCI'
#    ---------
# (0008, 103e) Series Description                  LO: 'Pre-operative, 1 - FLAIR - pineal - V1'
# (0008, 1070) Operators' Name                     PN: ''
# (0010, 0010) Patient's Name                      PN: 'ACNS0332_PARJIR'
# (0010, 0020) Patient ID                          LO: 'ACNS0332_PARJIR'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '010Y'
# (0012, 0050) Clinical Trial Time Point ID        LO: 'Pre-operative'
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'ACNS0332'
# (0013, 1013) Private tag data                    LO: '19591207'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.276497763958711721686365145696
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.534147.638.2321637500.20211122185513765
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '6'
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
# (0020, 1040) Position Reference Indicator        LO: ''
# (0040, 0555)  Acquisition Context Sequence  1 item(s) ----
#    (0040, a040) Value Type                          CS: 'CODE'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '126072'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#       ---------
#    (0040, a168)  Concept Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '262068006'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#       ---------
#    ---------
# (3006, 0002) Structure Set Label                 SH: 'Seed Point'
# (3006, 0008) Structure Set Date                  DA: '20211222'
# (3006, 0009) Structure Set Time                  TM: '185513'
# (3006, 0010)  Referenced Frame of Reference Sequence  1 item(s) ----
#    (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
#    (3006, 0012)  RT Referenced Study Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.276497763958711721686365145696
#       (3006, 0014)  RT Referenced Series Sequence  1 item(s) ----
#          (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.118865946438136982211944976786
#          (3006, 0016)  Contour Image Sequence  1 item(s) ----
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.157563254097513035055775127869
#             ---------
#          ---------
#       ---------
#    ---------
# (3006, 0020)  Structure Set ROI Sequence  1 item(s) ----
#    (3006, 0022) ROI Number                          IS: '1'
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
#    (3006, 0026) ROI Name                            LO: '1 - FLAIR - pineal - V1 - seed point'
#    (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
#    ---------
# (3006, 0039)  ROI Contour Sequence  1 item(s) ----
#    (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
#    (3006, 0040)  Contour Sequence  1 item(s) ----
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.157563254097513035055775127869
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: '1'
#       (3006, 0048) Contour Number                      IS: '1'
#       (3006, 0050) Contour Data                        DS: [-0.29316994871942503, 12.7742645918689, 7.345938845506385]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    ---------
# (3006, 0080)  RT ROI Observations Sequence  1 item(s) ----
#    (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '45793000'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#       ---------
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '49755003'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#       ---------
#    (3006, 0082) Observation Number                  IS: '1'
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    (3006, 0085) ROI Observation Label               SH: '1 - FLAIR - pineal - V1 - seed point'
#    (3006, 0086)  RT ROI Identification Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '79654002'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Edema'
#       ---------
#    (3006, 00a4) RT ROI Interpreted Type             CS: ''
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
# Processing SEG file:  PARJIR//Annotations/1-Pre-Operative/SEG_20211223_002722_556_S26.dcm
# Processing RTSS file:  PARJIR//Annotations/1-Pre-Operative/AIM_20211223_002741_885_S26.dcm
# DETECTED ROI NAME:  Restricted Diffusion
# Input SeriesDescription:  1 - DIFF - pineal - V1
# PatientName:  ACNS0332_PARJIR
# PatientAge:  010Y
# PatientSex:  M
# SeriesDescription:  Pre-operative, 1 - DIFF - pineal - V1
# SegmentSequence[0].SegmentLabel:  Restricted Diffusion
# segmentation_code:  (0008, 0100) Code Value                          SH: 'C81175'
# (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
# (0008, 0104) Code Meaning                        LO: 'Non-Enhancing Lesion'
# roi_name:  Restricted Diffusion
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '262068006'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#    ---------
# Output SeriesDescription:  Pre-operative, 1 - DIFF - pineal - V1
# (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '45793000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#    ---------
# (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '49755003'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#    ---------
# (0062, 0004) Segment Number                      US: 1
# (0062, 0005) Segment Label                       LO: 'Restricted Diffusion'
# (0062, 0008) Segment Algorithm Type              CS: 'MANUAL'
# (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'C81175'
#    (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#    (0008, 0104) Code Meaning                        LO: 'Non-Enhancing Lesion'
#    ---------
# (0062, 0020) Tracking ID                         UT: Array of 20 elements
# (0062, 0021) Tracking UID                        UI: 2.25.244304104175290246376252700917730902179
# Saved file  PARJIR//Annotations/1-Pre-Operative/SEG_20211223_002722_556_S26.dcm
# SeriesDescription:  Pre-operative, 1 - DIFF - pineal - V1
# segmentation_code:  (0008, 0100) Code Value                          SH: 'C81175'
# (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
# (0008, 0104) Code Meaning                        LO: 'Non-Enhancing Lesion'
# roi_name:  Restricted Diffusion
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '262068006'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#    ---------
# (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
# (3006, 0040)  Contour Sequence  1 item(s) ----
#    (3006, 0016)  Contour Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.320986736983668609384960542568
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'POINT'
#    (3006, 0046) Number of Contour Points            IS: '1'
#    (3006, 0048) Contour Number                      IS: '1'
#    (3006, 0050) Contour Data                        DS: [-4.38803431304415, 9.221839602140065, 12.6983673720389]
#    ---------
# (3006, 0084) Referenced ROI Number               IS: '1'
# (3006, 0022) ROI Number                          IS: '1'
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
# (3006, 0026) ROI Name                            LO: '1 - DIFF - pineal - V1 - seed point'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 182
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.534147.638.2321637500.20211122185746144
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.534147.638.2321637500.20211122185746144
# (0008, 0020) Study Date                          DA: '19591207'
# (0008, 0021) Series Date                         DA: '20211222'
# (0008, 0030) Study Time                          TM: '075838.875000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTSTRUCT'
# (0008, 0070) Manufacturer                        LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 0110)  Coding Scheme Identification Sequence  3 item(s) ----
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 010c) Coding Scheme UID                   UI: DICOM Controlled Terminology
#    (0008, 0115) Coding Scheme Name                  ST: 'DICOM Controlled Terminology'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'DICOM'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.6.96
#    (0008, 0115) Coding Scheme Name                  ST: 'SNOMED CT'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'SNOMED International'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.3.26.1.1
#    (0008, 0115) Coding Scheme Name                  ST: 'NCI Thesaurus'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'NCI'
#    ---------
# (0008, 103e) Series Description                  LO: 'Pre-operative, 1 - DIFF - pineal - V1'
# (0008, 1070) Operators' Name                     PN: ''
# (0010, 0010) Patient's Name                      PN: 'ACNS0332_PARJIR'
# (0010, 0020) Patient ID                          LO: 'ACNS0332_PARJIR'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '010Y'
# (0012, 0050) Clinical Trial Time Point ID        LO: 'Pre-operative'
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'ACNS0332'
# (0013, 1013) Private tag data                    LO: '19591207'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.276497763958711721686365145696
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.534147.638.2321637500.20211122185746144.4
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '26'
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
# (0020, 1040) Position Reference Indicator        LO: ''
# (0040, 0555)  Acquisition Context Sequence  1 item(s) ----
#    (0040, a040) Value Type                          CS: 'CODE'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '126072'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#       ---------
#    (0040, a168)  Concept Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '262068006'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#       ---------
#    ---------
# (3006, 0002) Structure Set Label                 SH: 'Seed Point'
# (3006, 0008) Structure Set Date                  DA: '20211222'
# (3006, 0009) Structure Set Time                  TM: '185746'
# (3006, 0010)  Referenced Frame of Reference Sequence  1 item(s) ----
#    (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
#    (3006, 0012)  RT Referenced Study Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.276497763958711721686365145696
#       (3006, 0014)  RT Referenced Series Sequence  1 item(s) ----
#          (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.310223825916677578694289004355
#          (3006, 0016)  Contour Image Sequence  1 item(s) ----
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.320986736983668609384960542568
#             ---------
#          ---------
#       ---------
#    ---------
# (3006, 0020)  Structure Set ROI Sequence  1 item(s) ----
#    (3006, 0022) ROI Number                          IS: '1'
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
#    (3006, 0026) ROI Name                            LO: '1 - DIFF - pineal - V1 - seed point'
#    (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
#    ---------
# (3006, 0039)  ROI Contour Sequence  1 item(s) ----
#    (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
#    (3006, 0040)  Contour Sequence  1 item(s) ----
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.320986736983668609384960542568
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: '1'
#       (3006, 0048) Contour Number                      IS: '1'
#       (3006, 0050) Contour Data                        DS: [-4.38803431304415, 9.221839602140065, 12.6983673720389]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    ---------
# (3006, 0080)  RT ROI Observations Sequence  1 item(s) ----
#    (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '45793000'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#       ---------
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '49755003'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#       ---------
#    (3006, 0082) Observation Number                  IS: '1'
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    (3006, 0085) ROI Observation Label               SH: '1 - DIFF - pineal - V1 - seed point'
#    (3006, 0086)  RT ROI Identification Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C81175'
#       (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#       (0008, 0104) Code Meaning                        LO: 'Non-Enhancing Lesion'
#       ---------
#    (3006, 00a4) RT ROI Interpreted Type             CS: ''
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
# Processing SEG file:  PARJIR//Annotations/1-Pre-Operative/SEG_20220307_142454_416_S29.dcm
# Processing RTSS file:  PARJIR//Annotations/1-Pre-Operative/AIM_20220307_142514_400_S29.dcm
# DETECTED ROI NAME:  Enhancing Lesion
# Input SeriesDescription:  1 - T1 post - SAG - pineal - V1
# PatientName:  ACNS0332_PARJIR
# PatientAge:  010Y
# PatientSex:  M
# SeriesDescription:  Pre-operative, 1 - T1 post - SAG - pineal - V1
# SegmentSequence[0].SegmentLabel:  Enhancing Lesion
# segmentation_code:  (0008, 0100) Code Value                          SH: 'C113842'
# (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
# (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
# roi_name:  Enhancing Lesion
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '262068006'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#    ---------
# Output SeriesDescription:  Pre-operative, 1 - T1 post - SAG - pineal - V1
# (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '45793000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#    ---------
# (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '49755003'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#    ---------
# (0062, 0004) Segment Number                      US: 1
# (0062, 0005) Segment Label                       LO: 'Enhancing Lesion'
# (0062, 0008) Segment Algorithm Type              CS: 'MANUAL'
# (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'C113842'
#    (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#    (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
#    ---------
# (0062, 0020) Tracking ID                         UT: 'Enhancing_Lesion'
# (0062, 0021) Tracking UID                        UI: 2.25.191465688770867204140652933651558585028
# Saved file  PARJIR//Annotations/1-Pre-Operative/SEG_20220307_142454_416_S29.dcm
# SeriesDescription:  Pre-operative, 1 - T1 post - SAG - pineal - V1
# segmentation_code:  (0008, 0100) Code Value                          SH: 'C113842'
# (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
# (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
# roi_name:  Enhancing Lesion
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '262068006'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#    ---------
# (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
# (3006, 0040)  Contour Sequence  1 item(s) ----
#    (3006, 0016)  Contour Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.100425816390605270968649148060
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'POINT'
#    (3006, 0046) Number of Contour Points            IS: '1'
#    (3006, 0048) Contour Number                      IS: '1'
#    (3006, 0050) Contour Data                        DS: [-1.16572969354205, 14.311852606676501, 7.7184786877772105]
#    ---------
# (3006, 0084) Referenced ROI Number               IS: '1'
# (3006, 0022) ROI Number                          IS: '1'
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
# (3006, 0026) ROI Name                            LO: '1 - T1 post - SAG - pineal - V1- seed point'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 178
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.534147.638.2321637500.20222785838569
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.534147.638.2321637500.20222785838569
# (0008, 0020) Study Date                          DA: '19591207'
# (0008, 0021) Series Date                         DA: '20220307'
# (0008, 0030) Study Time                          TM: '075838.875000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTSTRUCT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 0110)  Coding Scheme Identification Sequence  3 item(s) ----
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 010c) Coding Scheme UID                   UI: DICOM Controlled Terminology
#    (0008, 0115) Coding Scheme Name                  ST: 'DICOM Controlled Terminology'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'DICOM'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.6.96
#    (0008, 0115) Coding Scheme Name                  ST: 'SNOMED CT'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'SNOMED International'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.3.26.1.1
#    (0008, 0115) Coding Scheme Name                  ST: 'NCI Thesaurus'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'NCI'
#    ---------
# (0008, 103e) Series Description                  LO: 'Pre-operative, 1 - T1 post - SAG - pineal - V1'
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'TrioTim'
# (0010, 0010) Patient's Name                      PN: 'ACNS0332_PARJIR'
# (0010, 0020) Patient ID                          LO: 'ACNS0332_PARJIR'
# (0010, 0030) Patient's Birth Date                DA: '00021130'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '010Y'
# (0012, 0050) Clinical Trial Time Point ID        LO: 'Pre-operative'
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'ACNS0332'
# (0013, 1013) Private tag data                    LO: '19591207'
# (0018, 1020) Software Versions                   LO: 'syngo MR B13 4VB13A'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.276497763958711721686365145696
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.534147.638.2321637500.20222785838569.4
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '29'
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
# (0020, 1040) Position Reference Indicator        LO: ''
# (0040, 0555)  Acquisition Context Sequence  1 item(s) ----
#    (0040, a040) Value Type                          CS: 'CODE'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '126072'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#       ---------
#    (0040, a168)  Concept Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '262068006'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#       ---------
#    ---------
# (3006, 0002) Structure Set Label                 SH: 'Seed Point'
# (3006, 0008) Structure Set Date                  DA: '20220307'
# (3006, 0009) Structure Set Time                  TM: '085838'
# (3006, 0010)  Referenced Frame of Reference Sequence  1 item(s) ----
#    (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
#    (3006, 0012)  RT Referenced Study Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.276497763958711721686365145696
#       (3006, 0014)  RT Referenced Series Sequence  1 item(s) ----
#          (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.585371091614335524524223923423
#          (3006, 0016)  Contour Image Sequence  1 item(s) ----
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.100425816390605270968649148060
#             ---------
#          ---------
#       ---------
#    ---------
# (3006, 0020)  Structure Set ROI Sequence  1 item(s) ----
#    (3006, 0022) ROI Number                          IS: '1'
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
#    (3006, 0026) ROI Name                            LO: '1 - T1 post - SAG - pineal - V1- seed point'
#    (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
#    ---------
# (3006, 0039)  ROI Contour Sequence  1 item(s) ----
#    (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
#    (3006, 0040)  Contour Sequence  1 item(s) ----
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.100425816390605270968649148060
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: '1'
#       (3006, 0048) Contour Number                      IS: '1'
#       (3006, 0050) Contour Data                        DS: [-1.16572969354205, 14.311852606676501, 7.7184786877772105]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    ---------
# (3006, 0080)  RT ROI Observations Sequence  1 item(s) ----
#    (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '45793000'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#       ---------
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '49755003'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#       ---------
#    (3006, 0082) Observation Number                  IS: '1'
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    (3006, 0085) ROI Observation Label               SH: '1 - T1 post - SAG - pineal - V1- seed point'
#    (3006, 0086)  RT ROI Identification Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C113842'
#       (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#       (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
#       ---------
#    (3006, 00a4) RT ROI Interpreted Type             CS: ''
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
# Processing SEG file:  PARJIR//Annotations/1-Pre-Operative/SEG_20220307_142204_961_S30.dcm
# Processing RTSS file:  PARJIR//Annotations/1-Pre-Operative/AIM_20220307_142226_817_S30.dcm
# DETECTED ROI NAME:  Enhancing Lesion
# Input SeriesDescription:  1 - T1 post - AX - pineal - V1
# PatientName:  ACNS0332_PARJIR
# PatientAge:  010Y
# PatientSex:  M
# SeriesDescription:  Pre-operative, 1 - T1 post - AX - pineal - V1
# SegmentSequence[0].SegmentLabel:  Enhancing Lesion
# segmentation_code:  (0008, 0100) Code Value                          SH: 'C113842'
# (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
# (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
# roi_name:  Enhancing Lesion
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '262068006'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#    ---------
# Output SeriesDescription:  Pre-operative, 1 - T1 post - AX - pineal - V1
# (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '45793000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#    ---------
# (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '49755003'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#    ---------
# (0062, 0004) Segment Number                      US: 1
# (0062, 0005) Segment Label                       LO: 'Enhancing Lesion'
# (0062, 0008) Segment Algorithm Type              CS: 'MANUAL'
# (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'C113842'
#    (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#    (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
#    ---------
# (0062, 0020) Tracking ID                         UT: 'Enhancing_Lesion'
# (0062, 0021) Tracking UID                        UI: 2.25.191465688770867204140652933651558585028
# Saved file  PARJIR//Annotations/1-Pre-Operative/SEG_20220307_142204_961_S30.dcm
# SeriesDescription:  Pre-operative, 1 - T1 post - AX - pineal - V1
# segmentation_code:  (0008, 0100) Code Value                          SH: 'C113842'
# (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
# (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
# roi_name:  Enhancing Lesion
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '262068006'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#    ---------
# (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
# (3006, 0040)  Contour Sequence  1 item(s) ----
#    (3006, 0016)  Contour Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.935647197671479361108086909739
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'POINT'
#    (3006, 0046) Number of Contour Points            IS: '1'
#    (3006, 0048) Contour Number                      IS: '1'
#    (3006, 0050) Contour Data                        DS: [-1.4774550068202201, 13.80131995724165, 9.33971529381272]
#    ---------
# (3006, 0084) Referenced ROI Number               IS: '1'
# (3006, 0022) ROI Number                          IS: '1'
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
# (3006, 0026) ROI Name                            LO: '1 - T1 post - AX - pineal - V1 - seed point'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 178
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.534147.638.2321637500.2022278555283
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.534147.638.2321637500.2022278555283
# (0008, 0020) Study Date                          DA: '19591207'
# (0008, 0021) Series Date                         DA: '20220307'
# (0008, 0030) Study Time                          TM: '075838.875000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTSTRUCT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 0110)  Coding Scheme Identification Sequence  3 item(s) ----
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 010c) Coding Scheme UID                   UI: DICOM Controlled Terminology
#    (0008, 0115) Coding Scheme Name                  ST: 'DICOM Controlled Terminology'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'DICOM'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.6.96
#    (0008, 0115) Coding Scheme Name                  ST: 'SNOMED CT'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'SNOMED International'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.3.26.1.1
#    (0008, 0115) Coding Scheme Name                  ST: 'NCI Thesaurus'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'NCI'
#    ---------
# (0008, 103e) Series Description                  LO: 'Pre-operative, 1 - T1 post - AX - pineal - V1'
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'TrioTim'
# (0010, 0010) Patient's Name                      PN: 'ACNS0332_PARJIR'
# (0010, 0020) Patient ID                          LO: 'ACNS0332_PARJIR'
# (0010, 0030) Patient's Birth Date                DA: '00021130'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '010Y'
# (0012, 0050) Clinical Trial Time Point ID        LO: 'Pre-operative'
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'ACNS0332'
# (0013, 1013) Private tag data                    LO: '19591207'
# (0018, 1020) Software Versions                   LO: 'syngo MR B13 4VB13A'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.276497763958711721686365145696
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.534147.638.2321637500.2022278555283.4
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '30'
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
# (0020, 1040) Position Reference Indicator        LO: ''
# (0040, 0555)  Acquisition Context Sequence  1 item(s) ----
#    (0040, a040) Value Type                          CS: 'CODE'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '126072'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#       ---------
#    (0040, a168)  Concept Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '262068006'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Pre-operative'
#       ---------
#    ---------
# (3006, 0002) Structure Set Label                 SH: 'Seed Point'
# (3006, 0008) Structure Set Date                  DA: '20220307'
# (3006, 0009) Structure Set Time                  TM: '085552'
# (3006, 0010)  Referenced Frame of Reference Sequence  1 item(s) ----
#    (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.474142317475414573504726637349
#    (3006, 0012)  RT Referenced Study Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.276497763958711721686365145696
#       (3006, 0014)  RT Referenced Series Sequence  1 item(s) ----
#          (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.133707348426261300194248861386
#          (3006, 0016)  Contour Image Sequence  1 item(s) ----
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.935647197671479361108086909739
#             ---------
#          ---------
# ...
#          (3006, 0016)  Contour Image Sequence  1 item(s) ----
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.124803622793195983637815059651
#             ---------
#          ---------
#       ---------
#    ---------
# (3006, 0020)  Structure Set ROI Sequence  1 item(s) ----
#    (3006, 0022) ROI Number                          IS: '1'
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.211554932627412554862404640650
#    (3006, 0026) ROI Name                            LO: '3 - T1 post  - AX - pineal - V1 - seed point'
#    (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
#    ---------
# (3006, 0039)  ROI Contour Sequence  1 item(s) ----
#    (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
#    (3006, 0040)  Contour Sequence  1 item(s) ----
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.124803622793195983637815059651
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: '1'
#       (3006, 0048) Contour Number                      IS: '1'
#       (3006, 0050) Contour Data                        DS: [0.93385359413453, -1.8496437828141499, 24.0695196701489]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    ---------
# (3006, 0080)  RT ROI Observations Sequence  1 item(s) ----
#    (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '45793000'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#       ---------
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '49755003'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#       ---------
#    (3006, 0082) Observation Number                  IS: '1'
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    (3006, 0085) ROI Observation Label               SH: '3 - T1 post  - AX - pineal - V1 - seed point'
#    (3006, 0086)  RT ROI Identification Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C113842'
#       (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#       (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
#       ---------
#    (3006, 00a4) RT ROI Interpreted Type             CS: ''
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
# Processing SEG file:  PARJIR//Annotations/3-Post-Radiation/SEG_20220307_142847_415_S14.dcm
# Processing RTSS file:  PARJIR//Annotations/3-Post-Radiation/AIM_20220307_142903_567_S14.dcm
# DETECTED ROI NAME:  Enhancing Lesion
# Input SeriesDescription:  3 - T1 post - COR - pineal - V1
# PatientName:  ACNS0332_PARJIR
# PatientAge:  010Y
# PatientSex:  M
# SeriesDescription:  Post-radiation, 3 - T1 post - COR - pineal - V1
# SegmentSequence[0].SegmentLabel:  Enhancing Lesion
# segmentation_code:  (0008, 0100) Code Value                          SH: 'C113842'
# (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
# (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
# roi_name:  Enhancing Lesion
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '264908009'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Post-radiation'
#    ---------
# Output SeriesDescription:  Post-radiation, 3 - T1 post - COR - pineal - V1
# (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '45793000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#    ---------
# (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '49755003'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#    ---------
# (0062, 0004) Segment Number                      US: 1
# (0062, 0005) Segment Label                       LO: 'Enhancing Lesion'
# (0062, 0008) Segment Algorithm Type              CS: 'MANUAL'
# (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'C113842'
#    (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#    (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
#    ---------
# (0062, 0020) Tracking ID                         UT: 'Enhancing_Lesion'
# (0062, 0021) Tracking UID                        UI: 2.25.191465688770867204140652933651558585028
# Saved file  PARJIR//Annotations/3-Post-Radiation/SEG_20220307_142847_415_S14.dcm
# SeriesDescription:  Post-radiation, 3 - T1 post - COR - pineal - V1
# segmentation_code:  (0008, 0100) Code Value                          SH: 'C113842'
# (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
# (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
# roi_name:  Enhancing Lesion
# (0040, a040) Value Type                          CS: 'CODE'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '126072'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#    ---------
# (0040, a168)  Concept Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '264908009'
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 0104) Code Meaning                        LO: 'Post-radiation'
#    ---------
# (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
# (3006, 0040)  Contour Sequence  1 item(s) ----
#    (3006, 0016)  Contour Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.861692765532389005808897413408
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'POINT'
#    (3006, 0046) Number of Contour Points            IS: '1'
#    (3006, 0048) Contour Number                      IS: '1'
#    (3006, 0050) Contour Data                        DS: [1.6627712126260952, -5.10749517218935, 21.692129955404297]
#    ---------
# (3006, 0084) Referenced ROI Number               IS: '1'
# (3006, 0022) ROI Number                          IS: '1'
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.211554932627412554862404640650
# (3006, 0026) ROI Name                            LO: '3 - T1 post - COR - pineal - V1 - seed point'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 178
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.534147.638.2321637500.2022279227313
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-2.0'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.534147.638.2321637500.2022279227313
# (0008, 0020) Study Date                          DA: '19600315'
# (0008, 0021) Series Date                         DA: '20220307'
# (0008, 0030) Study Time                          TM: '125201.312000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTSTRUCT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 0110)  Coding Scheme Identification Sequence  3 item(s) ----
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 010c) Coding Scheme UID                   UI: DICOM Controlled Terminology
#    (0008, 0115) Coding Scheme Name                  ST: 'DICOM Controlled Terminology'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'DICOM'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.6.96
#    (0008, 0115) Coding Scheme Name                  ST: 'SNOMED CT'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'SNOMED International'
#    ---------
#    (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#    (0008, 010c) Coding Scheme UID                   UI: 2.16.840.1.113883.3.26.1.1
#    (0008, 0115) Coding Scheme Name                  ST: 'NCI Thesaurus'
#    (0008, 0116) Coding Scheme Responsible Organizat ST: 'NCI'
#    ---------
# (0008, 103e) Series Description                  LO: 'Post-radiation, 3 - T1 post - COR - pineal - V1'
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Avanto'
# (0010, 0010) Patient's Name                      PN: 'ACNS0332_PARJIR'
# (0010, 0020) Patient ID                          LO: 'ACNS0332_PARJIR'
# (0010, 0030) Patient's Birth Date                DA: '00021130'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '010Y'
# (0012, 0050) Clinical Trial Time Point ID        LO: 'Post-radiation'
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'ACNS0332'
# (0013, 1013) Private tag data                    LO: '19600315'
# (0018, 1020) Software Versions                   LO: 'syngo MR B13 4VB13A'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.188968367562190353294437961674
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.534147.638.2321637500.2022279227314
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '14'
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.211554932627412554862404640650
# (0020, 1040) Position Reference Indicator        LO: ''
# (0040, 0555)  Acquisition Context Sequence  1 item(s) ----
#    (0040, a040) Value Type                          CS: 'CODE'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '126072'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Time Point Type'
#       ---------
#    (0040, a168)  Concept Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '264908009'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Post-radiation'
#       ---------
#    ---------
# (3006, 0002) Structure Set Label                 SH: 'Seed Point'
# (3006, 0008) Structure Set Date                  DA: '20220307'
# (3006, 0009) Structure Set Time                  TM: '090227'
# (3006, 0010)  Referenced Frame of Reference Sequence  1 item(s) ----
#    (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.211554932627412554862404640650
#    (3006, 0012)  RT Referenced Study Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.188968367562190353294437961674
#       (3006, 0014)  RT Referenced Series Sequence  1 item(s) ----
#          (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.993929518965140333831667422252
#          (3006, 0016)  Contour Image Sequence  1 item(s) ----
#             (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#             (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.861692765532389005808897413408
#             ---------
#          ---------
#       ---------
#    ---------
# (3006, 0020)  Structure Set ROI Sequence  1 item(s) ----
#    (3006, 0022) ROI Number                          IS: '1'
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.211554932627412554862404640650
#    (3006, 0026) ROI Name                            LO: '3 - T1 post - COR - pineal - V1 - seed point'
#    (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
#    ---------
# (3006, 0039)  ROI Contour Sequence  1 item(s) ----
#    (3006, 002a) ROI Display Color                   IS: [255, 255, 0]
#    (3006, 0040)  Contour Sequence  1 item(s) ----
#       (3006, 0016)  Contour Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1610.1210.861692765532389005808897413408
#          ---------
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: '1'
#       (3006, 0048) Contour Number                      IS: '1'
#       (3006, 0050) Contour Data                        DS: [1.6627712126260952, -5.10749517218935, 21.692129955404297]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    ---------
# (3006, 0080)  RT ROI Observations Sequence  1 item(s) ----
#    (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '45793000'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Pineal gland'
#       ---------
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '49755003'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Morphologically Abnormal Structure'
#       ---------
#    (3006, 0082) Observation Number                  IS: '1'
#    (3006, 0084) Referenced ROI Number               IS: '1'
#    (3006, 0085) ROI Observation Label               SH: '3 - T1 post - COR - pineal - V1 - seed point'
#    (3006, 0086)  RT ROI Identification Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C113842'
#       (0008, 0102) Coding Scheme Designator            SH: 'NCIt'
#       (0008, 0104) Code Meaning                        LO: 'Enhancing Lesion'
#       ---------
#    (3006, 00a4) RT ROI Interpreted Type             CS: ''
#    (3006, 00a6) ROI Interpreter                     PN: ''
#    ---------
# Post-chemotherapy FOUND
# Processing SEG file:  PARJIR//Annotations/4-Post-Chemotherapy/SEG_20220307_124413_183_S4.dcm
# Processing RTSS file:  PARJIR//Annotations/4-Post-Chemotherapy/AIM_20220307_124555_534_S7.dcm
# ERROR: series numbers do not match.
# Recurrence FOUND
